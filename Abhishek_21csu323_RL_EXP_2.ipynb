# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn

data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * np.random.randn(1000) + 50)


plt.scatter(data1, data2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn, randint

data1 = randint(1, 10000,size = 100)
data2 = [-i for i in data1]

plt.scatter(data1, data2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn


data1 = 20 * randn(1000) + 100
data2 = 20 * randn(1000) + 100

plt.scatter(data1, data2)
plt.show()

# %%
import pandas as pd
data = pd.read_csv("student-mat.csv")
#print(data)
correlation = data['age'].corr(data['Medu'])
print(f"Correlation between 'age' and 'medu': {correlation:.2f}")
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv("student-mat.csv")

# Pair Plot (scatter plots for multiple variables)
sns.pairplot(data[['age', 'Medu', 'failures', 'studytime']])
plt.suptitle("Pair Plot of Age, Mother's Education, Failures, and Study Time", y=1.02)
plt.show()

# Heatmap (correlation matrix)                                                                            ``````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````````
correlation_matrix = data[['age', 'Medu', 'failures', 'studytime']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# Joint Plot (scatter plot with histograms)
sns.jointplot(data=data, x='age', y='Medu', kind='scatter')
plt.suptitle("Joint Plot of Age and Mother's Education")
plt.show()
